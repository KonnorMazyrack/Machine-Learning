# %%
import numpy as np
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Load and preprocess data
diabetes = load_diabetes(as_frame=True)
print(diabetes.DESCR)

df = diabetes.frame
X = diabetes.data
y = diabetes.target

print(f'df: {df.shape}')
print(f'X: {X.shape}')
print(f'y: {y.shape}')

# First split: 80% and 20% (test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# Define MLPRegressor to match Keras model
model = MLPRegressor(
    hidden_layer_sizes=(64, 64),  # Two hidden layers with 64 units each
    activation='relu',            # ReLU activation
    solver='adam',               # Adam optimizer
    max_iter=500,                # Equivalent to EPOCHS
    batch_size=16,               # Equivalent to BATCH_SIZE
    random_state=42,             # For reproducibility
    verbose=True,                # Print training progress
    early_stopping=True,         # Enable early stopping
    validation_fraction=0.1,     # Use 10% of training data for internal validation
    n_iter_no_change=10,         # Stop if no improvement for 10 iterations
    tol=1e-4                     # Tolerance for convergence
)

# Train the model
model.fit(X_train, y_train)

# Test metrics (using X_test, y_test)
y_test_pred1 = model.predict(X_test)
mse1 = mean_squared_error(y_test, y_test_pred1)
r21 = r2_score(y_test, y_test_pred1)

model2 = MLPRegressor(
    hidden_layer_sizes=(100, 100),  # Two hidden layers with 64 units each
    activation='relu',            # ReLU activation
    solver='adam',               # Adam optimizer
    max_iter=1000,                # Equivalent to EPOCHS
    batch_size=32,               # Equivalent to BATCH_SIZE
    random_state=42,             # For reproducibility
    verbose=True,                # Print training progress
    early_stopping=True,         # Enable early stopping
    validation_fraction=0.1,     # Use 10% of training data for internal validation
    n_iter_no_change=10,         # Stop if no improvement for 10 iterations
    tol=1e-4                     # Tolerance for convergence
)

# Train the model2
model2.fit(X_train, y_train)

# Test metrics (using X_test, y_test)
y_test_pred2 = model2.predict(X_test)
mse2 = mean_squared_error(y_test, y_test_pred2)
r22 = r2_score(y_test, y_test_pred2)

model3 = MLPRegressor(
    hidden_layer_sizes=(32, 32),  # Two hidden layers with 64 units each
    activation='relu',            # ReLU activation
    solver='adam',               # Adam optimizer
    max_iter=100,                # Equivalent to EPOCHS
    batch_size=16,               # Equivalent to BATCH_SIZE
    random_state=42,             # For reproducibility
    verbose=True,                # Print training progress
    early_stopping=True,         # Enable early stopping
    validation_fraction=0.1,     # Use 10% of training data for internal validation
    n_iter_no_change=10,         # Stop if no improvement for 10 iterations
    tol=1e-4                     # Tolerance for convergence
)

# Train the model2
model3.fit(X_train, y_train)

# Test metrics (using X_test, y_test)
y_test_pred3 = model3.predict(X_test)
mse3 = mean_squared_error(y_test, y_test_pred3)
r23 = r2_score(y_test, y_test_pred3)
print(f"(Model1) R2 Accuracy Score: {r21:.4f}")
print(f"(Model1) MSE: {mse1:.4f}")
print(f"(Model2) R2 Accuracy Score: {r22:.4f}")
print(f"(Model2) MSE: {mse2:.4f}")
print(f"(Model3) R2 Accuracy Score: {r23:.4f}")
print(f"(Model3) MSE: {mse3:.4f}")
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
#     - s6      glu, blood sugar level
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of `n_samples` (i.e. the sum of squares of each column totals 1).
#
# Source URL:
# https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#
# For more information see:
# Bradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.
# (https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)
#
# df: (442, 11)
# X: (442, 10)
# y: (442,)
# Iteration 1, loss = 15039.77480395
# Validation score: -4.086004
# Iteration 2, loss = 14955.53427451
# Validation score: -4.055329
# Iteration 3, loss = 14862.88209321
# Validation score: -4.015396
# Iteration 4, loss = 14732.60593132
# Validation score: -3.957770
# Iteration 5, loss = 14534.65042308
# Validation score: -3.870286
# Iteration 6, loss = 14239.23973171
# Validation score: -3.740355
# Iteration 7, loss = 13810.61082476
# Validation score: -3.559690
# Iteration 8, loss = 13226.76947731
# Validation score: -3.321507
# Iteration 9, loss = 12457.66351788
# Validation score: -3.029336
# Iteration 10, loss = 11541.41771264
# Validation score: -2.675245
# Iteration 11, loss = 10477.41603269
# Validation score: -2.272996
# Iteration 12, loss = 9284.77474606
# Validation score: -1.847557
# Iteration 13, loss = 8047.35253644
# Validation score: -1.408665
# Iteration 14, loss = 6786.49221422
# Validation score: -0.995899
# Iteration 15, loss = 5607.95276200
# Validation score: -0.627965
# Iteration 16, loss = 4580.34980938
# Validation score: -0.318188
# Iteration 17, loss = 3746.07547989
# Validation score: -0.078579
# Iteration 18, loss = 3111.09484868
# Validation score: 0.081302
# Iteration 19, loss = 2676.71064621
# Validation score: 0.175729
# Iteration 20, loss = 2416.55639810
# Validation score: 0.228398
# Iteration 21, loss = 2262.07301311
# Validation score: 0.252327
# Iteration 22, loss = 2173.44426626
# Validation score: 0.262784
# Iteration 23, loss = 2124.65889467
# Validation score: 0.268590
# Iteration 24, loss = 2087.31252710
# Validation score: 0.272493
# Iteration 25, loss = 2058.18524284
# Validation score: 0.276168
# Iteration 26, loss = 2032.48508440
# Validation score: 0.279767
# Iteration 27, loss = 2007.86234545
# Validation score: 0.284568
# Iteration 28, loss = 1983.89141425
# Validation score: 0.288934
# Iteration 29, loss = 1961.56293149
# Validation score: 0.291476
# Iteration 30, loss = 1942.55519541
# Validation score: 0.296621
# Iteration 31, loss = 1919.21268665
# Validation score: 0.298706
# Iteration 32, loss = 1901.73728829
# Validation score: 0.300291
# Iteration 33, loss = 1881.92187540
# Validation score: 0.304226
# Iteration 34, loss = 1864.47270775
# Validation score: 0.305635
# Iteration 35, loss = 1848.85918688
# Validation score: 0.309377
# Iteration 36, loss = 1833.04842245
# Validation score: 0.309771
# Iteration 37, loss = 1815.07994755
# Validation score: 0.312905
# Iteration 38, loss = 1799.67239107
# Validation score: 0.314667
# Iteration 39, loss = 1785.11843566
# Validation score: 0.315750
# Iteration 40, loss = 1771.76323462
# Validation score: 0.317261
# Iteration 41, loss = 1758.50170234
# Validation score: 0.318195
# Iteration 42, loss = 1744.69503516
# Validation score: 0.319661
# Iteration 43, loss = 1733.05085093
# Validation score: 0.320602
# Iteration 44, loss = 1724.07786813
# Validation score: 0.321223
# Iteration 45, loss = 1710.79907712
# Validation score: 0.323251
# Iteration 46, loss = 1698.73907227
# Validation score: 0.323528
# Iteration 47, loss = 1691.87375570
# Validation score: 0.325503
# Iteration 48, loss = 1678.10121633
# Validation score: 0.325898
# Iteration 49, loss = 1669.81899650
# Validation score: 0.324591
# Iteration 50, loss = 1660.41094440
# Validation score: 0.325254
# Iteration 51, loss = 1649.73395810
# Validation score: 0.326634
# Iteration 52, loss = 1643.26239823
# Validation score: 0.327423
# Iteration 53, loss = 1634.63833316
# Validation score: 0.327460
# Iteration 54, loss = 1624.91169426
# Validation score: 0.328752
# Iteration 55, loss = 1619.37403036
# Validation score: 0.328412
# Iteration 56, loss = 1611.19701639
# Validation score: 0.328715
# Iteration 57, loss = 1603.75375642
# Validation score: 0.329117
# Iteration 58, loss = 1596.07739652
# Validation score: 0.329930
# Iteration 59, loss = 1590.26437309
# Validation score: 0.329655
# Iteration 60, loss = 1584.74295000
# Validation score: 0.329636
# Iteration 61, loss = 1577.59830493
# Validation score: 0.331220
# Iteration 62, loss = 1572.39517555
# Validation score: 0.331061
# Iteration 63, loss = 1566.87406932
# Validation score: 0.330861
# Iteration 64, loss = 1561.84866194
# Validation score: 0.331959
# Iteration 65, loss = 1554.69682050
# Validation score: 0.331325
# Iteration 66, loss = 1549.90418462
# Validation score: 0.330919
# Iteration 67, loss = 1544.79917831
# Validation score: 0.332132
# Iteration 68, loss = 1542.74411712
# Validation score: 0.331586
# Iteration 69, loss = 1537.10681350
# Validation score: 0.331680
# Iteration 70, loss = 1532.35548795
# Validation score: 0.331845
# Iteration 71, loss = 1527.42434872
# Validation score: 0.332595
# Iteration 72, loss = 1525.90666591
# Validation score: 0.333800
# Iteration 73, loss = 1522.51379825
# Validation score: 0.331087
# Iteration 74, loss = 1518.06027383
# Validation score: 0.333275
# Iteration 75, loss = 1512.60219244
# Validation score: 0.332533
# Iteration 76, loss = 1508.11576984
# Validation score: 0.332945
# Iteration 77, loss = 1505.95489895
# Validation score: 0.333781
# Iteration 78, loss = 1503.10770309
# Validation score: 0.331960
# Iteration 79, loss = 1500.50668165
# Validation score: 0.331302
# Iteration 80, loss = 1496.82886345
# Validation score: 0.334575
# Iteration 81, loss = 1494.47901060
# Validation score: 0.333056
# Iteration 82, loss = 1491.53316316
# Validation score: 0.334331
# Iteration 83, loss = 1489.42651625
# Validation score: 0.334103
# Iteration 84, loss = 1488.28046998
# Validation score: 0.330003
# Iteration 85, loss = 1484.75589162
# Validation score: 0.333751
# Iteration 86, loss = 1480.72838881
# Validation score: 0.333917
# Iteration 87, loss = 1478.10979621
# Validation score: 0.334051
# Iteration 88, loss = 1480.96206076
# Validation score: 0.330264
# Iteration 89, loss = 1476.25296199
# Validation score: 0.334752
# Iteration 90, loss = 1471.83014759
# Validation score: 0.333680
# Iteration 91, loss = 1469.96045402
# Validation score: 0.333192
# Iteration 92, loss = 1468.27292688
# Validation score: 0.333249
# Iteration 93, loss = 1465.32519862
# Validation score: 0.332221
# Iteration 94, loss = 1466.02543030
# Validation score: 0.332083
# Iteration 95, loss = 1461.69028533
# Validation score: 0.333208
# Iteration 96, loss = 1463.06612403
# Validation score: 0.334687
# Iteration 97, loss = 1461.14861813
# Validation score: 0.332656
# Iteration 98, loss = 1457.76490077
# Validation score: 0.332625
# Iteration 99, loss = 1456.89719970
# Validation score: 0.333363
# Iteration 100, loss = 1456.61890847
# Validation score: 0.331278
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 14950.55694325
# Validation score: -4.427233
# Iteration 2, loss = 14863.26995225
# Validation score: -4.393221
# Iteration 3, loss = 14772.80350203
# Validation score: -4.357250
# Iteration 4, loss = 14671.63382330
# Validation score: -4.313512
# Iteration 5, loss = 14543.25991750
# Validation score: -4.256514
# Iteration 6, loss = 14373.62797447
# Validation score: -4.183372
# Iteration 7, loss = 14163.32665249
# Validation score: -4.088709
# Iteration 8, loss = 13890.50142953
# Validation score: -3.969877
# Iteration 9, loss = 13553.22414295
# Validation score: -3.821802
# Iteration 10, loss = 13126.48908341
# Validation score: -3.644266
# Iteration 11, loss = 12629.72282308
# Validation score: -3.431551
# Iteration 12, loss = 12038.00539372
# Validation score: -3.185100
# Iteration 13, loss = 11365.35377676
# Validation score: -2.902144
# Iteration 14, loss = 10568.65845950
# Validation score: -2.593831
# Iteration 15, loss = 9747.29867583
# Validation score: -2.250252
# Iteration 16, loss = 8829.33040043
# Validation score: -1.892695
# Iteration 17, loss = 7877.74545738
# Validation score: -1.532452
# Iteration 18, loss = 6924.05369429
# Validation score: -1.178285
# Iteration 19, loss = 6001.67864099
# Validation score: -0.843211
# Iteration 20, loss = 5129.17970182
# Validation score: -0.543794
# Iteration 21, loss = 4362.89313182
# Validation score: -0.285708
# Iteration 22, loss = 3701.46922401
# Validation score: -0.077953
# Iteration 23, loss = 3184.52441297
# Validation score: 0.078723
# Iteration 24, loss = 2785.69421007
# Validation score: 0.181729
# Iteration 25, loss = 2530.07637996
# Validation score: 0.243610
# Iteration 26, loss = 2348.78985665
# Validation score: 0.272455
# Iteration 27, loss = 2254.38965577
# Validation score: 0.284583
# Iteration 28, loss = 2194.75269564
# Validation score: 0.288785
# Iteration 29, loss = 2156.89410490
# Validation score: 0.291554
# Iteration 30, loss = 2132.45747307
# Validation score: 0.294453
# Iteration 31, loss = 2107.27791823
# Validation score: 0.298731
# Iteration 32, loss = 2087.05174036
# Validation score: 0.302463
# Iteration 33, loss = 2065.25792217
# Validation score: 0.307499
# Iteration 34, loss = 2046.74570732
# Validation score: 0.311700
# Iteration 35, loss = 2028.41594942
# Validation score: 0.316866
# Iteration 36, loss = 2011.03192734
# Validation score: 0.322725
# Iteration 37, loss = 1992.66445959
# Validation score: 0.325437
# Iteration 38, loss = 1976.73212518
# Validation score: 0.328725
# Iteration 39, loss = 1959.32503252
# Validation score: 0.331093
# Iteration 40, loss = 1944.82044309
# Validation score: 0.332557
# Iteration 41, loss = 1929.88039806
# Validation score: 0.336694
# Iteration 42, loss = 1916.96245408
# Validation score: 0.337464
# Iteration 43, loss = 1902.01304035
# Validation score: 0.343519
# Iteration 44, loss = 1887.07183212
# Validation score: 0.346089
# Iteration 45, loss = 1873.09136426
# Validation score: 0.349292
# Iteration 46, loss = 1861.68655336
# Validation score: 0.351312
# Iteration 47, loss = 1848.72678053
# Validation score: 0.352579
# Iteration 48, loss = 1836.23243541
# Validation score: 0.354917
# Iteration 49, loss = 1824.78989825
# Validation score: 0.357352
# Iteration 50, loss = 1812.88937373
# Validation score: 0.358982
# Iteration 51, loss = 1802.22651350
# Validation score: 0.360059
# Iteration 52, loss = 1791.63767158
# Validation score: 0.358938
# Iteration 53, loss = 1781.50447341
# Validation score: 0.363316
# Iteration 54, loss = 1771.08171106
# Validation score: 0.366079
# Iteration 55, loss = 1762.32213493
# Validation score: 0.363332
# Iteration 56, loss = 1751.45265006
# Validation score: 0.367552
# Iteration 57, loss = 1740.97568857
# Validation score: 0.367488
# Iteration 58, loss = 1731.92945394
# Validation score: 0.370135
# Iteration 59, loss = 1724.54508896
# Validation score: 0.367129
# Iteration 60, loss = 1714.35422989
# Validation score: 0.371648
# Iteration 61, loss = 1705.18243126
# Validation score: 0.372459
# Iteration 62, loss = 1698.41985536
# Validation score: 0.374988
# Iteration 63, loss = 1689.99029367
# Validation score: 0.369866
# Iteration 64, loss = 1680.85079173
# Validation score: 0.372601
# Iteration 65, loss = 1673.07708363
# Validation score: 0.371156
# Iteration 66, loss = 1665.38231681
# Validation score: 0.373934
# Iteration 67, loss = 1659.56896723
# Validation score: 0.378106
# Iteration 68, loss = 1650.55917398
# Validation score: 0.376908
# Iteration 69, loss = 1643.95189121
# Validation score: 0.374432
# Iteration 70, loss = 1637.76781029
# Validation score: 0.375620
# Iteration 71, loss = 1630.50427891
# Validation score: 0.374208
# Iteration 72, loss = 1625.49345237
# Validation score: 0.378091
# Iteration 73, loss = 1617.50086223
# Validation score: 0.376934
# Iteration 74, loss = 1613.43341239
# Validation score: 0.373143
# Iteration 75, loss = 1606.24883941
# Validation score: 0.376793
# Iteration 76, loss = 1600.06393514
# Validation score: 0.377937
# Iteration 77, loss = 1594.53006143
# Validation score: 0.375552
# Iteration 78, loss = 1589.04522178
# Validation score: 0.374119
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 15079.41907354
# Validation score: -4.159405
# Iteration 2, loss = 15022.22398589
# Validation score: -4.134876
# Iteration 3, loss = 14952.21725729
# Validation score: -4.105655
# Iteration 4, loss = 14867.56542219
# Validation score: -4.068221
# Iteration 5, loss = 14751.59216952
# Validation score: -4.016635
# Iteration 6, loss = 14595.10595168
# Validation score: -3.946114
# Iteration 7, loss = 14383.69159946
# Validation score: -3.853241
# Iteration 8, loss = 14098.37604691
# Validation score: -3.732285
# Iteration 9, loss = 13735.14548826
# Validation score: -3.575019
# Iteration 10, loss = 13266.87643714
# Validation score: -3.384327
# Iteration 11, loss = 12707.30512336
# Validation score: -3.153867
# Iteration 12, loss = 12050.26486145
# Validation score: -2.887137
# Iteration 13, loss = 11288.41767013
# Validation score: -2.592572
# Iteration 14, loss = 10454.16100569
# Validation score: -2.268621
# Iteration 15, loss = 9546.14699035
# Validation score: -1.927282
# Iteration 16, loss = 8602.19058777
# Validation score: -1.575850
# Iteration 17, loss = 7645.90064867
# Validation score: -1.229681
# Iteration 18, loss = 6699.77089504
# Validation score: -0.907809
# Iteration 19, loss = 5805.37650029
# Validation score: -0.615188
# Iteration 20, loss = 4990.30127135
# Validation score: -0.358588
# Iteration 21, loss = 4282.66183882
# Validation score: -0.143424
# Iteration 22, loss = 3682.94587037
# Validation score: 0.021321
# Iteration 23, loss = 3211.72045396
# Validation score: 0.141503
# Iteration 24, loss = 2843.57753927
# Validation score: 0.220090
# Iteration 25, loss = 2582.78594343
# Validation score: 0.268457
# Iteration 26, loss = 2403.39031043
# Validation score: 0.294509
# Iteration 27, loss = 2281.46611527
# Validation score: 0.305473
# Iteration 28, loss = 2207.18619699
# Validation score: 0.307798
# Iteration 29, loss = 2147.63484883
# Validation score: 0.307253
# Iteration 30, loss = 2112.55724929
# Validation score: 0.305541
# Iteration 31, loss = 2085.78520127
# Validation score: 0.302985
# Iteration 32, loss = 2063.22308359
# Validation score: 0.303612
# Iteration 33, loss = 2043.00324827
# Validation score: 0.302432
# Iteration 34, loss = 2025.88219886
# Validation score: 0.302272
# Iteration 35, loss = 2008.66837064
# Validation score: 0.305032
# Iteration 36, loss = 1992.27379748
# Validation score: 0.306857
# Iteration 37, loss = 1977.59220235
# Validation score: 0.305377
# Iteration 38, loss = 1961.89673597
# Validation score: 0.309631
# Iteration 39, loss = 1948.01369641
# Validation score: 0.312362
# Iteration 40, loss = 1934.44846008
# Validation score: 0.311369
# Iteration 41, loss = 1919.72648512
# Validation score: 0.312933
# Iteration 42, loss = 1906.96022287
# Validation score: 0.317236
# Iteration 43, loss = 1893.77531606
# Validation score: 0.316975
# Iteration 44, loss = 1881.70003917
# Validation score: 0.316840
# Iteration 45, loss = 1869.98944394
# Validation score: 0.320110
# Iteration 46, loss = 1857.57964881
# Validation score: 0.319725
# Iteration 47, loss = 1846.15612663
# Validation score: 0.320339
# Iteration 48, loss = 1838.25143286
# Validation score: 0.325387
# Iteration 49, loss = 1826.15282259
# Validation score: 0.320594
# Iteration 50, loss = 1813.93152040
# Validation score: 0.321440
# Iteration 51, loss = 1803.94013824
# Validation score: 0.324273
# Iteration 52, loss = 1794.20286374
# Validation score: 0.326253
# Iteration 53, loss = 1784.70528352
# Validation score: 0.324465
# Iteration 54, loss = 1776.11688707
# Validation score: 0.327818
# Iteration 55, loss = 1766.07719155
# Validation score: 0.325342
# Iteration 56, loss = 1757.72986568
# Validation score: 0.323463
# Iteration 57, loss = 1749.57233845
# Validation score: 0.321827
# Iteration 58, loss = 1739.42406145
# Validation score: 0.325691
# Iteration 59, loss = 1731.83154079
# Validation score: 0.327266
# Iteration 60, loss = 1723.54146418
# Validation score: 0.326978
# Iteration 61, loss = 1715.58369767
# Validation score: 0.325703
# Iteration 62, loss = 1711.04943693
# Validation score: 0.321560
# Iteration 63, loss = 1700.38752719
# Validation score: 0.325542
# Iteration 64, loss = 1693.03276061
# Validation score: 0.325090
# Iteration 65, loss = 1687.08135486
# Validation score: 0.325841
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# (Model1) R2 Accuracy Score: 0.4473
# (Model1) MSE: 2928.1445
# (Model2) R2 Accuracy Score: 0.4247
# (Model2) MSE: 3048.2849
# (Model3) R2 Accuracy Score: 0.4061
# (Model3) MSE: 3146.6752
